# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepali9894/SD_deepali_036/blob/main/sets%2Ctuple%2C_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [1,2,3,4,5,34]
l1 = []
for i in l:
 l1.append(i**2)
 print(l1)
# Out:
# [1]
# [1, 4]
# [1, 4, 9]
# [1, 4, 9, 16]
# [1, 4, 9, 16, 25]
# [1, 4, 9, 16, 25, 1156]

# %%
l =[1,2,3,4,5]

# %%
[i**2 for i in l]
# Out:
# [1, 4, 9, 16, 25]

# %%
l1 = ["deeps","yogita","muskan","shona"]

# %%
d = {"key1":1,"key2":2,"key3":3,"key4":4}

# %%
{k:v**2 for k , v in d.items()}
# Out:
# {'key1': 1, 'key2': 4, 'key3': 9, 'key4': 16}

# %%
a = 10

# %%
b = str(a)

# %%
b
# Out:
# '10'

# %%
t = (1,2,5,6,7)

# %%
l = list(t)

# %%
l
# Out:
# [1, 2, 5, 6, 7]

# %%
l1 = ["deeps","yogita",23,45]

# %%
t1 = tuple(l1)

# %%
t1
# Out:
# ('deeps', 'yogita', 23, 45)

# %%
set1 = {2,3,4,5,5,5,5,6}

# %%
set1
# Out:
# {2, 3, 4, 5, 6}

# %%
dict ={"key1":23, "key2":45}

# %%
dict
# Out:
# {'key1': 23, 'key2': 45}
