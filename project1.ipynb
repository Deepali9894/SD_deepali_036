# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepali9894/SD_deepali_036/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 M1 =int(input("Enter the M1: "))
 M2 =int(input("Enter the M2: "))
 M3 =int(input("Enter the M3: "))
 totalsum = (M1+M2+M3)
 score = totalsum/300*100
 print(score/10)
# Out:
# Enter the M1: 98
# Enter the M2: 97
# Enter the M3: 96
# 9.7
