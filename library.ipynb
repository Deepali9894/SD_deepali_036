# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepali9894/SD_deepali_036/blob/main/library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
l = [1,2,3,4]

# %%
ar = np.array(l)

# %%
type(l)
# Out:
# list

# %%
ar
# Out:
# array([1, 2, 3, 4])

# %%
type(ar)
# Out:
# numpy.ndarray

# %%
np.array([[1,2] ,[3,4]])
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np .asarray(l)
# Out:
# array([1, 2, 3, 4])

# %%
a = [2,3,4]

# %%
np.asanyarray(a)
# Out:
# array([2, 3, 4])

# %%
b = np.matrix(l)

# %%
b
# Out:
# matrix([[1, 2, 3, 4]])

# %%
 s = "deeps"

# %%
s[-1::-5]
# Out:
# 's'

# %%
s[-1::-4]
# Out:
# 'sd'
