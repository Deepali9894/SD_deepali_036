# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepali9894/SD_deepali_036/blob/main/polymorphism.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class UPI:
  def pay(self):
    print("payment through UPI")

class card:
  def pay(self):
    print("payment through card")

for payment in [UPI(),card()]:
  payment.pay()
# Out:
# payment through UPI
# payment through card

# %%
# Expense Tracker Program

    """Displays all recorded expenses by category."""
    if not expenses:
        print("No expenses recorded yet.")
        return
    print("\n--- Your Expense
def add_expense(expenses, category, amount):
    """Adds an expense to the expenses dictionary."""
    if category in expenses:
        expenses[category] += amount
    else:
        expenses[category] = amount
    print(f"Added {amount:.2f} to {category}.")

def view_expenses(expensess ---")
    for category, amount in expenses.items():
        print(f"{category}: ${amount:.2f}")
    print("--------------------")

def get_total_expenses(expenses):
    """Calculates and returns the total of all expenses."""
    total = sum(expenses.values())
    return total

def main():
    expenses = {} # Dictionary to store expenses: {category: amount}

    print("Welcome to your personal Expense Tracker!")

    while True:
        print("\nWhat would you like to do?")
        print("1. Add an expense")
        print("2. View all expenses")
        print("3. View total expenses")
        print("4. Exit")

        choice = input("Enter your choice (1-4): ")

        if choice == '1':
            category = input("Enter expense category (e.g., Food, Transport, Entertainment): ").strip().capitalize()
            try:
                amount = float(input("Enter amount spent: $"))
                if amount <= 0:
                    print("Amount must be positive.")
                else:
                    add_expense(expenses, category, amount)
            except ValueError:
                print("Invalid amount. Please enter a number.")
        elif choice == '2':
            view_expenses(expenses)
        elif choice == '3':
            total = get_total_expenses(expenses)
            print(f"\nYour total expenses are: ${total:.2f}")
        elif choice == '4':
            print("Exiting Expense Tracker. Goodbye!")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 4.")

if __name__ == '__main__':
    main()
# Out:
# Welcome to your personal Expense Tracker!
#
# What would you like to do?
# 1. Add an expense
# 2. View all expenses
# 3. View total expenses
# 4. Exit
#
# Your total expenses are: $0.00
#
# What would you like to do?
# 1. Add an expense
# 2. View all expenses
# 3. View total expenses
# 4. Exit
#
# Your total expenses are: $0.00
#
# What would you like to do?
# 1. Add an expense
# 2. View all expenses
# 3. View total expenses
# 4. Exit
# Added 1000.00 to Food.
#
# What would you like to do?
# 1. Add an expense
# 2. View all expenses
# 3. View total expenses
# 4. Exit

# %%
# Expense tracker
name = input("Enter you")
