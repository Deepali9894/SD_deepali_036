# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepali9894/SD_deepali_036/blob/main/OOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 1

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
class skills:
  def welcome_msg(self):
    print("welcome to skills")

# %%
rohan = skills()

# %%
print(type(rohan))
# Out:
# <class '__main__.skills'>

# %%
rohan.welcome_msg()
# Out:
# welcome to skills

# %%
gaurav = skills()

# %%
gaurav .welcome_msg()
# Out:
# welcome to skills

# %%
class skills1:
  def __init__(self,phone_number,email_id,student_id):
    self.phone_number = phone_number
    self.email_id = email_id
    self.student_id = student_id
    def return_student_details(self):
      return self.student_id,self.phone_number,self.email_id

# %%
rohan = skills1(989897,"deepa@gmail.com",101)

# %%
rohan.phone_number
# Out:
# 989897

# %%
gaurav = skills1(989689,"gaurav@gmail.com",102)

# %%
gaurav.phone_number
# Out:
# 989689

# %%
class skill2 :
  def __init__(self,phone_name,email_id,student_id):
    self. phone_number1 = phone_name
    self.email_id1 = email_id
    self.student_id1 = student_id
  def return_student_details(self):
    return self.student_id1,self.phone_number1,self.email_id1

# %%
yogita  = skill2(99989898, "yogita@gmail" ,104)

# %%
yogita.phone_number1
# Out:
# 99989898

# %%
yogita.email_id1
# Out:
# 'yogita@gmail'

# %%
yogita.return_student_details()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1546/3801892050.py in <cell line: 0>()
# ----> 1 yogita.return_student_details()
#
# AttributeError: 'skill2' object has no attribute 'return_student_details'
