# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepali9894/SD_deepali_036/blob/main/lamda_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 2
p= 3

# %%
def test (n,p):
    return(n**p)

# %%
test(3,8)
# Out:
# 6561

# %%
 a = lambda n, p :n**p

# %%
a(2,3)
# Out:
# 8

# %%
add = lambda x,y :x+y

# %%
add(98,2)
# Out:
# 100

# %%
add = lambda x,y,p,q :x+y+p+q

# %%
add (2,3,3,5)
# Out:
# 13

# %%
c_to_f = lambda c :(9/5)*c + 32

# %%
c_to_f(49)
# Out:
# 120.2

# %%
finding_max = lambda x,y : x if x>y else y

# %%
finding_max(34,23)
# Out:
# 34

# %%
s = 'skills'

# %%
find_len = lambda s : len(s)

# %%
find_len(s)
# Out:
# 6

# %%
l = [2,3,4,4,8]

# %%
def sq (x):
  return x**2

# %%
def test(l):
  l1 = []
  for i in l:
    l1.apppend(sq(i))
  return l1

# %%
list (map(sq,l))
# Out:
# [4, 9, 16, 16, 64]

# %%
list (map(lambda x :x**2,l))
# Out:
# [4, 9, 16, 16, 64]

# %%
l1 = [1,2,3,4,5]
l2 = [ 6,7,8,9,10]
list(map(lambda x,y :x+y,l1,l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
def add (x,y):
  return x+y

# %%
list (map(add ,l1 ,l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
s = "skills"
list(map(lambda s :s.upper(),s))
# Out:
# ['S', 'K', 'I', 'L', 'L', 'S']

# %%
from functools import  reduce

# %%
l = [1,2,3,3,4,5]

# %%
reduce(lambda x,y :x+y,l)
# Out:
# 18

# %%
reduce(lambda x,y,z : x+y+z ,l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1370/3463316403.py in <cell line: 0>()
# ----> 1 reduce(lambda x,y,z : x+y+z ,l)
#
# TypeError: <lambda>() missing 1 required positional argument: 'z'

# %%
reduce (lambda x,y : x+y ,[l])
# Out:
# [1, 2, 3, 3, 4, 5]

# %%
reduce (lambda x,y : x+y ,[1])
# Out:
# 1

# %%
list (filter(lambda x : x%2==0,l))
# Out:
# [2, 4]
