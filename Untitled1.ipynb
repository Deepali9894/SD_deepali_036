# %%
1+1
a = 10;

# %%
c = True

# %%
True * True
# Out:
# 1

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1225/2917913318.py in <cell line: 0>()
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
False/True
# Out:
# 0.0

# %%
s = "True"

# %%
print type(s)
# Out:
#   File "/tmp/ipykernel_1225/1462007187.py", line 1
#     print type(s)
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print(type(s))
# Out:
# <class 'str'>

# %%
t = "batch name is information technology "

# %%
 t[0:24:5]
# Out:
# 'b  na'

# %%
t[0:30:5]
# Out:
# 'b  na '

# %%
 t = "Batch name is computer science & Engineering"

# %%
t[-3:-44:-5]
# Out:
# 'ii&ermina'

# %%
y = 2;

# %%
type(y);

# %%
y = 3.7
type(y);

# %%
a = 4;
b = 12;
type(a)
# Out:
# int

# %%
print("hello doreamon")
# Out:
# hello doreamon

# %%
q = 89

# %%
t = 90

# %%
print(q+t)
# Out:
# 179

# %%
r = 8.9

# %%
type(r)
# Out:
# float

# %%
print ("doremon loves tea")
# Out:
# doremon loves tea

# %%
s = "SRMCEM"

# %%
[::-1]
# Out:
#   File "/tmp/ipykernel_1225/1964978068.py", line 1
#     [::-1]
#      ^
# SyntaxError: invalid syntax

# %%
[: : -1]
# Out:
#   File "/tmp/ipykernel_1225/3971233135.py", line 1
#     [: : -1]
#      ^
# SyntaxError: invalid syntax

# %%
s[: : -1]
# Out:
# 'MECMRS'

# %%
s[0 3 2]
# Out:
#   File "/tmp/ipykernel_1225/2027855327.py", line 1
#     s[0 3 2]
#       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
s[0:3:-5]
# Out:
# ''

# %%
S[: : -1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1225/4065401198.py in <cell line: 0>()
# ----> 1 S[: : -1]
#
# NameError: name 'S' is not defined

# %%
name =["name",'age','class']
values = ['deeps',19,'12th']
student = dict(zip(name, values))
print (student)
# Out:
#   File "/tmp/ipykernel_1034/4150280795.py", line 3
#     student = print dict(zip(name, values))
#               ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
